# %% [markdown]
# #### Experiment 1

# %%
import sys
from parsing import parse_matrix_and_gap
from alignment import global_alignment_affine,global_alignment_linear

import time
import random
import matplotlib.pyplot as plt

# %%
substitution_matrix, gaps = parse_matrix_and_gap("data/subst_matrix_l.txt")

# Generate random sequences of varying lengths
seq_lengths = range(1000, 20000, 1000)
seqs = []
for l in seq_lengths:
    seqs.append((''.join([random.choice(['A', 'C', 'G', 'T']) for _ in range(l)]),
                ''.join([random.choice(['A', 'C', 'G', 'T']) for _ in range(l)])))
    

alpha = gaps[0]
beta = gaps[1]

    
times = []
for v, w in seqs:
    start_time = time.time()
    global_alignment_affine(v.upper(), w.upper(), alpha,beta, substitution_matrix,sys.argv[4])
    end_time = time.time()
    times.append(end_time - start_time)

# %%
len(times)
# Out:
# 20

# %%
# Plot the results
plt.plot(seq_lengths[:20], times)
plt.xlabel('Sequence length')
plt.ylabel('Running time (seconds)')
plt.title('Running time of global_alignment_linear')
plt.show()

# %% [markdown]
# #### Experiment 2

# %%
substitution_matrix, gap_cost = parse_matrix_and_gap("data/subst_matrix_a.txt")

# Generate random sequences of varying lengths
seq_lengths = range(1000, 20000, 1500)
seqs = []
for l in seq_lengths:
    seqs.append((''.join([random.choice(['A', 'C', 'G', 'T']) for _ in range(l)]),
                ''.join([random.choice(['A', 'C', 'G', 'T']) for _ in range(l)])))
    

times = []
for v, w in seqs:
    start_time = time.time()
    global_alignment_linear(v, w, gap_cost,substitution_matrix)
    end_time = time.time()
    times.append(end_time - start_time)

# %%
len(times)

# %%
# Plot the results
plt.plot(seq_lengths[:20], times)
plt.xlabel('Sequence length')
plt.ylabel('Running time (seconds)')
plt.title('Running time of global_alignment_linear')
plt.show()
